# %%
#importaciones iniciales
import kagglehub
import pandas as pd
import os

# %%
#carga del dataset desde el mismo kaggle
path = kagglehub.dataset_download("austinreese/craigslist-carstrucks-data")

print(os.listdir(path))

df = pd.read_csv(os.path.join(path, "vehicles.csv"))
# Out:
# Using Colab cache for faster access to the 'craigslist-carstrucks-data' dataset.
# ['vehicles.csv']

# %%
# extraer primeras 10 filas
df_raw_sample = df.head(10)

# guardar en CSV
df_raw_sample.to_csv('datos_crudos_ejemplos.csv', index=False)
