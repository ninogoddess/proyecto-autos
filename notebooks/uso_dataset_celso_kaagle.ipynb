# %%
#USO DE MI PROPIO DATA SET EN KAGGLE
import kagglehub
import pandas as pd
import os

# Descargar dataset
path = kagglehub.dataset_download("celsofariasaraya/vehicules-processed-celso")

print("Path:", path)
print("Archivos disponibles:", os.listdir(path))

# Cargar el CSV (ajusta el nombre si es necesario)
df = pd.read_csv(os.path.join(path, "vehicles_processed.csv"))

# Mostrar primeras 10 filas
df.head(10)
# Out:
# Using Colab cache for faster access to the 'vehicules-processed-celso' dataset.
# Path: /kaggle/input/vehicules-processed-celso
# Archivos disponibles: ['vehicles_processed.csv']
#       price      year                        model    cylinders  odometer  \
# 0  0.329175  0.804878     sierra 1500 crew cab slt  8 cylinders  0.193075
# 1  0.218059  0.707317               silverado 1500  8 cylinders  0.237428
# 2  0.389783  0.951220          silverado 1500 crew  8 cylinders  0.063864
# 3  0.302911  0.878049         tundra double cab sr  8 cylinders  0.137078
# 4  0.141390  0.780488                    f-150 xlt  6 cylinders  0.426666
# 5  0.272607  0.756098  sierra 2500 hd extended cab  8 cylinders  0.228985
# 6  0.339276  0.853659        silverado 1500 double  6 cylinders  0.098327
# 7  0.343418  0.926829                       tacoma  6 cylinders  0.143331
# 8  0.292810  0.853659        colorado extended cab  6 cylinders  0.057670
# 9  0.379682  0.731707         corvette grand sport  8 cylinders  0.100787
#
#   title_status    drive paint_color state      lat  ...  type_truck  \
# 0        clean  unknown       white    al  32.5900  ...       False
# 1        clean  unknown        blue    al  32.5900  ...       False
# 2        clean  unknown         red    al  32.5900  ...       False
# 3        clean  unknown         red    al  32.5900  ...       False
# 4        clean      rwd       black    al  32.5920  ...        True
# 5        clean      4wd       black    al  32.5900  ...       False
# 6        clean      4wd      silver    al  32.5900  ...       False
# 7        clean      4wd        grey    al  32.6013  ...        True
# 8        clean      4wd         red    al  32.5900  ...       False
# 9        clean      rwd         red    al  32.5900  ...       False
#
#    type_unknown  type_van  type_wagon  condition_fair  condition_good  \
# 0         False     False       False           False            True
# 1         False     False       False           False            True
# 2         False     False       False           False            True
# 3         False     False       False           False            True
# 4         False     False       False           False           False
# 5         False     False       False           False            True
# 6         False     False       False           False            True
# 7         False     False       False           False           False
# 8         False     False       False           False            True
# 9         False     False       False           False            True
#
#    condition_like new  condition_new  condition_salvage  condition_unknown
# 0               False          False              False              False
# 1               False          False              False              False
# 2               False          False              False              False
# 3               False          False              False              False
# 4               False          False              False              False
# 5               False          False              False              False
# 6               False          False              False              False
# 7               False          False              False              False
# 8               False          False              False              False
# 9               False          False              False              False
#
# [10 rows x 76 columns]
