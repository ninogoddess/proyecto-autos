# %%
#USO DE MI PROPIO DATA SET EN KAGGLE
import kagglehub
import pandas as pd
import os

# Descargar dataset
path = kagglehub.dataset_download("celsofariasaraya/vehicules-processed-celso")

print("Path:", path)
print("Archivos disponibles:", os.listdir(path))

# Cargar el CSV (ajusta el nombre si es necesario)
df = pd.read_csv(os.path.join(path, "vehicles_processed_nums.csv"))

# Mostrar primeras 10 filas
df.head(10)
# Out:
# Using Colab cache for faster access to the 'vehicules-processed-celso' dataset.
# Path: /kaggle/input/vehicules-processed-celso
# Archivos disponibles: ['vehicles_processed_nums.csv', '.nfs0000000042972aa300000024']
#       price      year  cylinders  odometer       lat      long  \
# 0  1.003805  0.286422   1.424970 -0.562567 -0.808338  0.388228
# 1  0.222556 -0.364796   1.424970 -0.345289 -0.808338  0.388228
# 2  1.429940  1.263250   1.424970 -1.195538 -0.808338  0.388228
# 3  0.819146  0.774836   1.424970 -0.836882 -0.808338  0.388228
# 4 -0.316506  0.123618   0.791972  0.581740 -0.808049  0.386294
# 5  0.606078 -0.039187   1.424970 -0.386651 -0.808338  0.388228
# 6  1.074827  0.612031   0.791972 -1.026710 -0.808338  0.388228
# 7  1.103947  1.100445   0.791972 -0.806248 -0.806701  0.390019
# 8  0.748123  0.612031   0.791972 -1.225878 -0.808338  0.388228
# 9  1.358918 -0.201992   1.424970 -1.014659 -0.808338  0.388228
#
# ...
